# %%
import pandas as pd

# %%
df=pd.read_csv('bank.csv', sep=";")

# %%
df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# # Q1) How Many Campaign Available in this dataset

# %%
df['campaign'].sum()
# Out:
# 12630

# %% [markdown]
# # Q2) How Many Users do we have with Housing and Personal Loan

# %%
len(df[(df['housing'] == 'yes') & (df['loan'] == 'yes')])
# Out:
# 406

# %% [markdown]
# # Q3) How Many Persons do we have whose age is 60+

# %%
len(df[df['age'] >= 60])
# Out:
# 174

# %% [markdown]
# # Q4) In Which Month we have targeted most of the customer

# %%
df['month'].describe()
# Out:
# count     4521
# unique      12
# top        may
# freq      1398
# Name: month, dtype: object

# %% [markdown]
# # Q5) Which Mode of call is giving you more Results.

# %%
df['contact'].describe()
# Out:
# count         4521
# unique           3
# top       cellular
# freq          2896
# Name: contact, dtype: object

# %% [markdown]
# # Q6) How Many Enterpeures do we have in this list

# %%
len(df[df['job'] == 'entrepreneur'])
# Out:
# 168

# %% [markdown]
# # Q7) How Many Customers do we have with negative balnce.

# %%
len(df[df['balance'] < 0])
# Out:
# 366

# %% [markdown]
# # Q8) Prepare a group of data based on eduction level.

# %%
Group = df.groupby('education').agg(list)

# %%
Group
# Out:
#                                                          age  \
# education
# primary    [30, 43, 25, 55, 78, 55, 26, 32, 45, 41, 50, 6...
# secondary  [33, 59, 39, 39, 43, 20, 31, 56, 31, 44, 44, 5...
# tertiary   [35, 30, 35, 36, 41, 36, 40, 37, 42, 26, 41, 3...
# unknown    [38, 67, 61, 43, 48, 60, 56, 37, 41, 37, 57, 4...
#
#                                                          job  \
# education
# primary    [unemployed, services, blue-collar, blue-colla...
# secondary  [services, blue-collar, technician, services, ...
# tertiary   [management, management, management, self-empl...
# unknown    [management, retired, admin., blue-collar, adm...
#
#                                                      marital  \
# education
# primary    [married, married, single, married, divorced, ...
# secondary  [married, married, married, married, married, ...
# tertiary   [single, married, single, married, married, ma...
# unknown    [divorced, married, married, married, married,...
#
# ...
